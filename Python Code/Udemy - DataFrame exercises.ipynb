# %%
import pandas as pd

# %%
# specify path to file
sales = pd.read_csv("supermarket_sales.csv")

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# to see current working directory
import os
print(os.getcwd())
# Out:
# /Users/raulfernandogutierrez/Desktop/Coding/Python Code

# %%
# to change the source of the directory
#os.chdir('Users/raulfernandogutierrez/Desktop')

# %%
# number of rows
len(sales)
# Out:
# 1000

# %%
# list columns
sales.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
# number of columns
len(sales.columns)
# Out:
# 17

# %%
# return top rows
sales.head() # default is 5, but you can change to any number
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sales.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
# metadata stuff
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
# Invoice ID                 1000 non-null object
# Branch                     1000 non-null object
# City                       1000 non-null object
# Customer type              1000 non-null object
# Gender                     1000 non-null object
# Product line               1000 non-null object
# Unit price                 1000 non-null float64
# Quantity                   1000 non-null int64
# Tax 5%                     1000 non-null float64
# Total                      1000 non-null float64
# Date                       1000 non-null object
# Time                       1000 non-null object
# Payment                    1000 non-null object
# cogs                       1000 non-null float64
# gross margin percentage    1000 non-null float64
# gross income               1000 non-null float64
# Rating                     1000 non-null float64
# ...

# %%
# stats on the columns
sales.describe().transpose()
# Out:
#                           count        mean           std        min  \
# Unit price               1000.0   55.672130  2.649463e+01  10.080000
# Quantity                 1000.0    5.510000  2.923431e+00   1.000000
# Tax 5%                   1000.0   15.379369  1.170883e+01   0.508500
# Total                    1000.0  322.966749  2.458853e+02  10.678500
# cogs                     1000.0  307.587380  2.341765e+02  10.170000
# gross margin percentage  1000.0    4.761905  6.220360e-14   4.761905
# gross income             1000.0   15.379369  1.170883e+01   0.508500
# Rating                   1000.0    6.972700  1.718580e+00   4.000000
#
#                                 25%         50%         75%          max
# Unit price                32.875000   55.230000   77.935000    99.960000
# Quantity                   3.000000    5.000000    8.000000    10.000000
# Tax 5%                     5.924875   12.088000   22.445250    49.650000
# ...

# %%
# to rename columns, copy and paste from output and rename accordingly
sales.columns = ['InvoiceID', 'Branch', 'City', 'CustomerType', 'Gender',
       'ProductLine', 'UnitPrice', 'Quantity', 'Tax 5%', 'Total', 'Date',
       'Time', 'Payment', 'cogs', 'GrossMargin%', 'GrossIncome',
       'Rating']

# %%
# display renamed columns
sales.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  GrossMargin%  GrossIncome  Rating
# ...

# %%
# subsetting dataframe in Pandas
# -Rows
# -Columns
# -Combine the 2

# limiting rows
sales[30:50]
# Out:
#       InvoiceID Branch       City CustomerType  Gender  \
# 30  871-79-8483      B   Mandalay       Normal    Male
# 31  149-71-6266      B   Mandalay       Member    Male
# 32  640-49-2076      B   Mandalay       Normal    Male
# 33  595-11-5460      A     Yangon       Normal    Male
# 34  183-56-6882      C  Naypyitaw       Member  Female
# 35  232-16-2483      C  Naypyitaw       Member  Female
# 36  129-29-8530      A     Yangon       Member    Male
# 37  272-65-1806      A     Yangon       Normal  Female
# 38  333-73-7901      C  Naypyitaw       Normal  Female
# 39  777-82-7220      B   Mandalay       Member    Male
# 40  280-35-5823      B   Mandalay       Member  Female
# 41  554-53-8700      C  Naypyitaw       Member    Male
# 42  354-25-5821      B   Mandalay       Member  Female
# 43  228-96-1411      C  Naypyitaw       Member  Female
# 44  617-15-4209      C  Naypyitaw       Member    Male
# 45  132-32-9879      B   Mandalay       Member  Female
# ...

# %%
# limit from a number in the rows through the end
sales[900:]
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 900  377-79-7592      C  Naypyitaw       Member  Female
# 901  509-10-0516      B   Mandalay       Normal    Male
# 902  595-94-9924      A     Yangon       Member  Female
# 903  865-41-9075      A     Yangon       Normal    Male
# 904  545-07-8534      C  Naypyitaw       Normal  Female
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity   Tax 5%      Total  \
# 900  Electronic accessories      44.84         9  20.1780   423.7380
# 901      Home and lifestyle      45.97         4   9.1940   193.0740
# 902       Health and beauty      27.73         5   6.9325   145.5825
# ...

# %%
# only rows with a number as the interval
sales[::100]
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 100  163-56-7055      C  Naypyitaw       Member    Male
# 200  606-80-4905      C  Naypyitaw       Member  Female
# 300  446-47-6729      C  Naypyitaw       Normal    Male
# 400  110-05-6330      C  Naypyitaw       Normal  Female
# 500  277-63-2961      B   Mandalay       Member    Male
# 600  219-61-4139      C  Naypyitaw       Normal    Male
# 700  626-43-7888      C  Naypyitaw       Normal  Female
# 800  751-15-6198      B   Mandalay       Normal    Male
# 900  377-79-7592      C  Naypyitaw       Member  Female
#
#                 ProductLine  UnitPrice  Quantity   Tax 5%     Total  \
# 0         Health and beauty      74.69         7  26.1415  548.9715
# 100     Fashion accessories      48.71         1   2.4355   51.1455
# 200       Sports and travel      19.15         6   5.7450  120.6450
# 300     Fashion accessories      99.82         2   9.9820  209.6220
# ...

# %%
# select only specified columns

#sales['Branch','City','CustomerType', 'Gender', 'ProductLine', 'Date', 'UnitPrice', 'Quantity','Time','Payment']
sales['Gender'].head(25)
# Out:
# 0     Female
# 1     Female
# 2       Male
# 3       Male
# 4       Male
# 5       Male
# 6     Female
# 7     Female
# 8     Female
# 9     Female
# 10    Female
# 11      Male
# 12    Female
# 13      Male
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18      Male
# 19    Female
# 20      Male
# 21      Male
# 22      Male
# 23      Male
# 24      Male
# Name: Gender, dtype: object

# %%
sales[['Branch','City','CustomerType', 'Gender', 'ProductLine', 'Date', 'UnitPrice', 'Quantity','Time','Payment']].head(10)
# Out:
#   Branch       City CustomerType  Gender             ProductLine       Date  \
# 0      A     Yangon       Member  Female       Health and beauty   1/5/2019
# 1      C  Naypyitaw       Normal  Female  Electronic accessories   3/8/2019
# 2      A     Yangon       Normal    Male      Home and lifestyle   3/3/2019
# 3      A     Yangon       Member    Male       Health and beauty  1/27/2019
# 4      A     Yangon       Normal    Male       Sports and travel   2/8/2019
# 5      C  Naypyitaw       Normal    Male  Electronic accessories  3/25/2019
# 6      A     Yangon       Member  Female  Electronic accessories  2/25/2019
# 7      C  Naypyitaw       Normal  Female      Home and lifestyle  2/24/2019
# 8      A     Yangon       Member  Female       Health and beauty  1/10/2019
# 9      B   Mandalay       Member  Female      Food and beverages  2/20/2019
#
#    UnitPrice  Quantity   Time      Payment
# 0      74.69         7  13:08      Ewallet
# 1      15.28         5  10:29         Cash
# ...

# %%
# quick access to columns
sales.City
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
# select a subset of rows and columns
sales[0:10][['Gender','ProductLine']]

# trick (flip the subsets and get same results)
sales[['Gender', 'ProductLine']][0:10]
# Out:
#    Gender             ProductLine
# 0  Female       Health and beauty
# 1  Female  Electronic accessories
# 2    Male      Home and lifestyle
# 3    Male       Health and beauty
# 4    Male       Sports and travel
# 5    Male  Electronic accessories
# 6  Female  Electronic accessories
# 7  Female      Home and lifestyle
# 8  Female       Health and beauty
# 9  Female      Food and beverages

# %%
# drop columns
sales = sales.drop('cogs', 1) # axis is equal to 1 for (columns)

# %%
sales
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity   Tax 5%      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
# filtering DataFrames
sales.Quantity > 2
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999     True
# Name: Quantity, Length: 1000, dtype: bool

# %%
# adding those results to a variable
multiItems = sales.Quantity > 2

# %%
# take the filtered dataframe (purchased over 2 items) and pass it through the previous dataframe to filter out
sales[multiItems]
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 990  886-18-2897      A     Yangon       Normal  Female
# 991  602-16-6955      B   Mandalay       Normal  Female
# 993  690-01-6631      B   Mandalay       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity   Tax 5%      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
# create a DataFrame with male shoppers who purchsed more than 5 items
maleShoppers = (sales.Gender == 'Male') & (sales.Quantity > 5)

# %%
sales[maleShoppers]
# Out:
#        InvoiceID Branch       City CustomerType Gender  \
# 0    750-67-8428      A     Yangon       Member   Male
# 2    631-41-3108      A     Yangon       Normal   Male
# 3    123-19-1176      A     Yangon       Member   Male
# 4    373-73-7910      A     Yangon       Normal   Male
# 5    699-14-3026      C  Naypyitaw       Normal   Male
# ..           ...    ...        ...          ...    ...
# 989  430-53-4718      B   Mandalay       Member   Male
# 991  602-16-6955      B   Mandalay       Normal   Male
# 993  690-01-6631      B   Mandalay       Normal   Male
# 996  303-96-2227      B   Mandalay       Normal   Male
# 999  849-09-3807      A     Yangon       Member   Male
#
#                 ProductLine  UnitPrice  Quantity   Tax 5%      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# 3         Health and beauty      58.22         8  23.2880   489.0480
# ...

# %%
# get unique categories (similar to DISTINCT)
sales.ProductLine.unique() # unique Product Categories
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
# get unique categories (similar to DISTINCT)
sales.City.unique() # unique cities
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
sales[sales.City == 'Yangon']
# Out:
#        InvoiceID Branch    City CustomerType Gender             ProductLine  \
# 0    750-67-8428      A  Yangon       Member   Male       Health and beauty
# 2    631-41-3108      A  Yangon       Normal   Male      Home and lifestyle
# 3    123-19-1176      A  Yangon       Member   Male       Health and beauty
# 4    373-73-7910      A  Yangon       Normal   Male       Sports and travel
# 6    355-53-5943      A  Yangon       Member   Male  Electronic accessories
# ..           ...    ...     ...          ...    ...                     ...
# 990  886-18-2897      A  Yangon       Normal   Male      Food and beverages
# 992  745-74-0715      A  Yangon       Normal   Male  Electronic accessories
# 997  727-02-1313      A  Yangon       Member   Male      Food and beverages
# 998  347-56-2442      A  Yangon       Normal   Male      Home and lifestyle
# 999  849-09-3807      A  Yangon       Member   Male     Fashion accessories
#
# ...
