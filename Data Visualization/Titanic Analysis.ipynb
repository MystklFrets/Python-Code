# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

#read the csv file with Titanic data
titanic_df = pd.read_csv('full.csv')

titanic_df

#titanic_df.describe()

#trimming the dataframe - dropping columns
titanic_df.drop(['PassengerId','Embarked','WikiId','SibSp','Body'], axis=1).head()

#check where you are getting nulls
titanic_df.isnull()

titanic_df.isnull().sum()

#display bargraph showing lived vs died
pd.value_counts(titanic_df['Survived']).plot.bar()


titanic_df['Survived'].mean()

titanic_df.groupby(['Sex','Pclass']).mean()

titanic_df[titanic_df['Age']>18].groupby(['Sex','Pclass']).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1        714.341667  0.972973  39.358333  0.541667  0.466667
#        2        631.719512  0.900000  32.067073  0.487805  0.536585
#        3        648.425532  0.423729  29.457447  0.446809  0.755319
# male   1        660.608392  0.375000  42.716783  0.391608  0.265734
#        2        706.065693  0.071429  34.069343  0.343066  0.138686
#        3        629.010830  0.133663  29.799639  0.166065  0.126354
#
#                      Fare      WikiId   Age_wiki     Class
# Sex    Pclass
# female 1       111.502258  155.630252  38.899160  1.000000
#        2        22.482470  466.378049  32.304878  1.987805
#        3        13.448982  913.247312  29.677419  3.000000
# male   1        71.890794  169.125874  42.538462  1.000000
#        2        19.254531  454.007299  33.875912  1.978102
#        3        10.042917  937.289855  29.481884  3.000000
